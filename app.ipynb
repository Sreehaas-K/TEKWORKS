# %%
import pandas as pd

# %%
df = pd.read_csv('transactions.csv')
df
# Out:
#            t_date  cust_id   t_amt            services  \
# 0      06-26-2015  4007024   40.33  Exercise & Fitness
# 1      05-26-2015  4006742  198.44  Exercise & Fitness
# 2      06-01-2015  4009775    5.58  Exercise & Fitness
# 3      06-05-2015  4002199  198.19          Gymnastics
# 4      12-17-2015  4002613   98.81         Team Sports
# ...           ...      ...     ...                 ...
# 49995  09-18-2015  4005664   53.95               Games
# 49996  10-02-2015  4007287  163.81               Games
# 49997  05-03-2015  4003954   35.85      Racquet Sports
# 49998  10-23-2015  4007843  180.41          Gymnastics
# 49999  12-14-2015  4001406  168.49         Team Sports
#
#                            products_used         city       state t_details
# 0             Cardio Machine Accessories  Clarksville   Tennessee    credit
# 1                   Weightlifting Gloves   Long Beach  California    credit
# 2      Weightlifting Machine Accessories      Anaheim  California    credit
# 3                       Gymnastics Rings    Milwaukee   Wisconsin    credit
# 4                           Field Hockey  Nashville     Tennessee    credit
# ...                                  ...          ...         ...       ...
# 49995                         Dice Games       Irving       Texas    credit
# 49996                 Poker Chips & Sets  Kansas City    Missouri    credit
# 49997                             Squash  New Orleans   Louisiana      cash
# 49998                    Vaulting Horses     Berkeley  California    credit
# 49999                      Team Handball     Rockford    Illinois    credit
#
# [50000 rows x 8 columns]

# %%
total = df['t_amt'].sum()
total
# Out:
# np.float64(5110820.54)

# %%
#2
m = pd.to_datetime(df['t_date'],errors = "coerce",dayfirst=True)
# Out:
# C:\Users\sreeh\AppData\Local\Temp\ipykernel_43980\3123434121.py:2: UserWarning: Parsing dates in %m-%d-%Y format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   m = pd.to_datetime(df['t_date'],errors = "coerce",dayfirst=True)

# %%
a = m.dt.month_name()
a
# Out:
# 0             June
# 1              May
# 2             June
# 3             June
# 4         December
#            ...
# 49995    September
# 49996      October
# 49997          May
# 49998      October
# 49999     December
# Name: t_date, Length: 50000, dtype: object

# %%
df['month'] = a
df['month']
# Out:
# 0             June
# 1              May
# 2             June
# 3             June
# 4         December
#            ...
# 49995    September
# 49996      October
# 49997          May
# 49998      October
# 49999     December
# Name: month, Length: 50000, dtype: object

# %%
k = df.groupby('month')['t_amt'].sum().idxmax()
k
# Out:
# 'March'

# %%
#3
av = df.groupby('cust_id')['t_amt'].mean()
av
# Out:
# cust_id
# 4000000    127.444000
# 4000001    108.945556
# 4000002     56.165000
# 4000003    123.670000
# 4000004    168.135000
#               ...
# 4009995     65.018571
# 4009996    104.515000
# 4009997    121.547500
# 4009998    110.950000
# 4009999     85.252500
# Name: t_amt, Length: 9926, dtype: float64

# %%
#4
s = df.loc(df.groupby('month')['t_amt'],)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Anaconda\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: <pandas.core.groupby.generic.SeriesGroupBy object at 0x000002792764F350>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43980\1863927461.py in ?()
#       1 #4
# ----> 2 s = df.loc(df.groupby('month')['t_amt'],)
#       3 s
#
# d:\Anaconda\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# --> 738             axis_int_none = self.obj._get_axis_number(axis)
#     739         else:
#     740             axis_int_none = axis
#     741         new_self.axis = axis_int_none
#
# d:\Anaconda\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named <pandas.core.groupby.generic.SeriesGroupBy object at 0x000002792764F350> for object type DataFrame

# %%
#5
z = df['t_amt'].idxmax()
z
# Out:
# 36291

# %%
#6  Which service category contributes the most to total revenue?
g = df.groupby('services')['t_amt'].sum().idxmax()
g
# Out:
# 'Outdoor Recreation'

# %%
#7  Which product generated the highest revenue?

p = df.groupby('products_used')['t_amt'].sum().idxmax()
p
# Out:
# 'Yoga & Pilates'

# %%
#8  How does the average transaction amount vary between services?
avgg = df['t_amt'].mean()
avgg
# Out:
# np.float64(102.2164108)

# %%
avtr = df['t_amt'] - avgg
avtr
# Out:
# 0       -61.886411
# 1        96.223589
# 2       -96.636411
# 3        95.973589
# 4        -3.406411
#            ...
# 49995   -48.266411
# 49996    61.593589
# 49997   -66.366411
# 49998    78.193589
# 49999    66.273589
# Name: t_amt, Length: 50000, dtype: float64

# %%
df['avgtr'] = avtr
x = df.groupby('services')['avgtr'].sum().sort_index
x
# Out:
# <bound method Series.sort_index of services
# Air Sports                 1189.145632
# Combat Sports             -1882.079604
# Dancing                     286.115929
# Exercise & Fitness        10675.728545
# Games                       207.338007
# Gymnastics                  541.691083
# Indoor Games               2402.306171
# Jumping                    -123.397762
# Outdoor Play Equipment    -2721.475428
# Outdoor Recreation       -10201.531736
# Puzzles                    -991.693410
# Racquet Sports             2305.422201
# Team Sports                3140.751092
# Water Sports              -1651.477965
# Winter Sports             -3176.842755
# Name: avgtr, dtype: float64>

# %%
#9  How many unique customers made purchases?
unique = df['cust_id'].nunique()
unique
# Out:
# 9926

# %%
#10  Which customers have spent the most overall?

most = df.groupby('cust_id')['t_amt'].sum().idxmax()
most
# Out:
# np.int64(4009485)

# %%
#11  What is the average number of transactions per customer?
tc = df.groupby('cust_id').size()
avgt = tc.mean()

avgt
# Out:
# np.float64(5.037275841225066)

# %%
#12 Are there customers who made multiple purchases in different categories?
cc = df.groupby('cust_id')['services'].nunique()
mc = cc[cc > 1]

mc
# Out:
# cust_id
# 4000000    4
# 4000001    8
# 4000002    2
# 4000003    3
# 4000004    3
#           ..
# 4009995    4
# 4009996    6
# 4009997    4
# 4009998    4
# 4009999    5
# Name: services, Length: 9488, dtype: int64

# %%
#13 What percentage of customers are repeat buyers?
repeat = df.groupby('cust_id').size()
rb = repeat[repeat > 1].count()
total_customers = df['cust_id'].nunique()
percentage = (rb / total_customers * 100)
percentage
# Out:
# np.float64(96.5645778762845)

# %%
#14 Which product category has the highest total sales?
pc = df.groupby('products_used')['t_amt'].sum().idxmax()
pc
# Out:
# 'Yoga & Pilates'

# %%
#15 Which services are most popular by transaction count?
p = df['services'].value_counts().idxmax()
p
# Out:
# 'Outdoor Recreation'

# %%
#16 For each service, which product type is purchased most frequently?

# %%
#17 What is the average transaction amount per product type?
at = df.groupby('products_used')['t_amt'].mean()
at
# Out:
# products_used
# Abdominal Equipment    105.362798
# Air Hockey             103.775478
# Air Suits              101.421832
# Archery                 97.345564
# Badminton              108.441138
#                           ...
# Wetsuits               102.042775
# Whitewater Rafting     102.877744
# Windsurfing            104.161453
# Wrestling               97.895364
# Yoga & Pilates         107.668784
# Name: t_amt, Length: 125, dtype: float64

# %%
#18 Are there specific services where customers spend significantly more?
ss = df.groupby('services')['t_amt'].sum()
ss
# Out:
# services
# Air Sports                 99316.90
# Combat Sports             164730.67
# Dancing                    42603.71
# Exercise & Fitness        766463.87
# Games                     374932.70
# Gymnastics                327225.34
# Indoor Games              288506.04
# Jumping                   205842.67
# Outdoor Play Equipment    294728.28
# Outdoor Recreation        846678.64
# Puzzles                    61564.75
# Racquet Sports            166976.06
# Team Sports               617461.38
# Water Sports              531815.97
# Winter Sports             321973.56
# Name: t_amt, dtype: float64

# %%
#19 Which state has the highest total sales?
ss = df.groupby('state')['t_amt'].sum()
ss.idxmax()
# Out:
# 'California'

# %%
#20 Which city records the highest number of transactions?
ct = df['city'].value_counts()
ct.idxmax()
# Out:
# 'Pasadena'
